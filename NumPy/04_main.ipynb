# %% [markdown]
# Random

# %% [markdown]
# Rand()

# %%
import numpy as np
Value = (10)

result = np.random.rand(Value, dtype=int)

print(f"Random Rand Array: \n{result}")
print(f"Array Shape: {result.shape}")
